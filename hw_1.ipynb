# %% [markdown]
# ### Задание 1
#
# Дана переменная, в которой хранится четырёхзначное число (год). Необходимо написать программу, которая выведет, является этот год високосным или обычным.
#
# #### Пример работы программы
#
# > **Input A:** `year = 2020`
# > **Output A:** `Високосный год`
#
# > **Input B:** `year = 2019`
# > **Output B:** `Обычный год`

# %% [markdown]
# ### Решение 1

# %%
leap = 'Високосный год'
not_leap = 'Обычный год'

# %%
def get_year_type():
    year = int(input())

    if year % 100 == 0:
        if year % 400 == 0:
            return leap
        else:
            return not_leap
    if year % 4 == 0: 
       return leap
    else:
       return not_leap

# %%
isLeapYear()
# Out:
#  2016
# 'Високосный год'

# %% [markdown]
# ### Задание 2 (необязательное)
#
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли этот билет счастливым. Билет считается счастливым, если сумма первых трёх цифр совпадает с суммой последних трёх цифр номера.
#
# ##### Примеры работы программы
#
#
# > **Input A:**
# `number = 123456`
# > **Output A:**
# `Несчастливый билет`
#
# > **Input B:** `number = 123321`
# > **Output B:** `Счастливый билет`

# %%
win = 'Счастливый билет'
lose = 'Несчастливый билет'

# %%
def get_win_ticket():
    number = int(input())
    left = number // 1000
    right = number % 1000
    
    left_sum = sum(map(int, str(left)))
    right_sum = sum(map(int, str(right)))

    res = left_sum == right_sum
    
    if res:
        print(win)
    else:
        print(lose)

# %%
get_win_ticket()
# Out:
#  123456
# Несчастливый билет
